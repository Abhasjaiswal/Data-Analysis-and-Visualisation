# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('./datasets/iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.drop("Species",axis=1,inplace=True)
df.head(30)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0    1            5.1           3.5            1.4           0.2
# 1    2            4.9           3.0            1.4           0.2
# 2    3            4.7           3.2            1.3           0.2
# 3    4            4.6           3.1            1.5           0.2
# 4    5            5.0           3.6            1.4           0.2
# 5    6            5.4           3.9            1.7           0.4
# 6    7            4.6           3.4            1.4           0.3
# 7    8            5.0           3.4            1.5           0.2
# 8    9            4.4           2.9            1.4           0.2
# 9   10            4.9           3.1            1.5           0.1
# 10  11            5.4           3.7            1.5           0.2
# 11  12            4.8           3.4            1.6           0.2
# 12  13            4.8           3.0            1.4           0.1
# ...

# %%
df.drop(2,axis=0,inplace=True)

# %%
df.drop([3, 5, 10], axis=0,inplace=True)
df.head(10)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0    1            5.1           3.5            1.4           0.2
# 1    2            4.9           3.0            1.4           0.2
# 4    5            5.0           3.6            1.4           0.2
# 6    7            4.6           3.4            1.4           0.3
# 7    8            5.0           3.4            1.5           0.2
# 8    9            4.4           2.9            1.4           0.2
# 9   10            4.9           3.1            1.5           0.1
# 11  12            4.8           3.4            1.6           0.2
# 12  13            4.8           3.0            1.4           0.1
# 13  14            4.3           3.0            1.1           0.1

# %%
df.drop(index=[4, 7, 11], columns=['SepalWidthCm', 'PetalWidthCm'],inplace=True)
df.head(10)
# Out:
#     Id  SepalLengthCm  PetalLengthCm
# 0    1            5.1            1.4
# 1    2            4.9            1.4
# 6    7            4.6            1.4
# 8    9            4.4            1.4
# 9   10            4.9            1.5
# 12  13            4.8            1.4
# 13  14            4.3            1.1
# 14  15            5.8            1.2
# 15  16            5.7            1.5
# 16  17            5.4            1.3

# %%
df=df.rename(columns={'SepalLengthCm':'SLcm','PetalLengthCm':'PLcm'})
df.head(10)
# Out:
#     Id  SLcm  PLcm
# 0    1   5.1   1.4
# 1    2   4.9   1.4
# 6    7   4.6   1.4
# 8    9   4.4   1.4
# 9   10   4.9   1.5
# 12  13   4.8   1.4
# 13  14   4.3   1.1
# 14  15   5.8   1.2
# 15  16   5.7   1.5
# 16  17   5.4   1.3

# %%
df.duplicated().head(10)
# Out:
# 0     False
# 1     False
# 6     False
# 8     False
# 9     False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# dtype: bool

# %%
duplicate_rows = df[df.duplicated()]
print("number of duplicate rows : ", duplicate_rows.shape)
# Out:
# number of duplicate rows :  (0, 3)

# %%
df.count()
# Out:
# Id      143
# SLcm    143
# PLcm    143
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Id      0
# SLcm    0
# PLcm    0
# dtype: int64

# %%
df=df.dropna()
df.count()
# Out:
# Id      143
# SLcm    143
# PLcm    143
# dtype: int64

# %%
df
# Out:
#       Id  SLcm  PLcm
# 0      1   5.1   1.4
# 1      2   4.9   1.4
# 6      7   4.6   1.4
# 8      9   4.4   1.4
# 9     10   4.9   1.5
# ..   ...   ...   ...
# 145  146   6.7   5.2
# 146  147   6.3   5.0
# 147  148   6.5   5.2
# 148  149   6.2   5.4
# 149  150   5.9   5.1
#
# [143 rows x 3 columns]

# %%
sns.boxplot(data=df)
plt.show()

# %%
sns.boxplot(x=df["SLcm"])
plt.show()

# %%
plt.hist(df['SLcm'], bins=10, edgecolor='black')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.title('Histogram of Sepal Length')
plt.show()

# %%
for column in df.select_dtypes(include=['number']):
    plt.hist(df[column])
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {column}')
    plt.show()

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
sns.scatterplot(x='SLcm', y='PLcm', data=df)
plt.show()
